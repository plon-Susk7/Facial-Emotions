# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('landmark_differences_csvs/iim/ANG.csv')

# %%
df
# Out:
#             1          2         3          4          5          6         7  \
# 0    9.220590 -78.316611  1.869155 -13.440535   5.084080 -38.430755 -1.641926
# 1    5.715767 -95.683477  1.752590 -13.031707   3.501524 -54.341699 -0.713365
# 2  -14.382719 -31.509220 -2.757869  -4.353071  -8.338483 -18.850054  4.026701
# 3   -9.303392 -67.248328 -2.878966  -9.330277  -6.313413 -37.473874  0.824865
# 4   -9.178518  45.700793 -1.625618   9.978361  -5.458479  18.850414  2.336277
# ..        ...        ...       ...        ...        ...        ...       ...
# 95 -18.683378 -76.074006 -3.013108 -12.343178 -10.042047 -44.148899  4.671328
# 96 -18.843754  12.464553 -4.792988   6.706877 -12.333130  11.488042  4.371251
# 97  -0.830588 -39.710647  0.830608  -6.767513  -0.205098 -20.693564 -0.329483
# 98  -3.838484 -24.417252 -0.517995  -1.104342  -1.999952  -9.047369  1.481955
# 99  16.661161 -67.044604  3.962465 -16.124949  10.035547 -46.923719 -2.590528
#
#             8         9        10  ...           927           928       929  \
# 0   11.095710 -0.160976 -1.468059  ...  0.000000e+00 -1.136868e-13  1.353365
# 1   17.869159  0.279830  5.027249  ...  2.273737e-13  1.136868e-13  1.713748
# 2    6.906078 -0.104393  2.452635  ... -1.136868e-13 -2.273737e-13  1.361119
# 3   13.068745 -1.269273  3.364872  ...  0.000000e+00 -1.136868e-13  0.076704
# 4   -4.379525  0.099520  4.578791  ... -1.136868e-13 -2.273737e-13  1.234181
# ..        ...       ...       ...  ...           ...           ...       ...
# 95  16.757930  0.704481  2.790820  ...  0.000000e+00 -2.273737e-13  1.301619
# 96  -5.781545 -0.983814  1.583554  ...  1.136868e-13  0.000000e+00  0.265162
# 97   4.801786  0.265825 -0.349550  ... -2.273737e-13 -1.136868e-13  1.130735
# 98   1.415768  0.057874  1.324252  ... -1.136868e-13  1.136868e-13  0.581143
# 99  17.852668  0.606312  0.759068  ...  2.273737e-13  0.000000e+00  1.382872
#
#          930       931       932       933        934       935        936
# 0   0.721741  1.506614  3.413305 -2.367341   6.002252 -2.419777  11.138652
# 1   3.625881  2.164081  9.879347 -2.690209   4.661906  0.361642  23.669442
# 2   4.148987  2.124274  7.687405  1.956086   4.143633  2.875861  10.119777
# 3   1.653268 -0.034251  4.604621 -0.027661   4.930551 -0.046635  12.339769
# 4   3.893960  1.129249  5.281607  2.241142  -4.320333  4.379826   1.886652
# ..       ...       ...       ...       ...        ...       ...        ...
# 95  1.081171  2.711130  4.756968 -2.496507   4.384254  0.123551  15.412906
# 96  1.868600  0.867177  2.317974  6.479814   1.150228  6.250448   1.368944
# 97  1.063773  1.396241  2.951390 -0.808428   1.582890  1.502958   8.868068
# 98  0.014857  0.616259  0.728493  0.405848   1.472011  0.892888   7.058384
# 99  2.102311  1.202545  7.546664 -3.284530  11.066224 -1.477041  14.335514
#
# [100 rows x 936 columns]

# %%
temp_lst = []

for i in range(df.shape[0]):

    row = list(df.iloc[i])
    temp_lst.append([sum(row[0::2]),sum(row[1::2])])

# %%
df = pd.read_csv('landmark_differences_csvs/radboud/ANG.csv')
temp_lst = []

for i in range(df.shape[0]):

    row = list(df.iloc[i])
    temp_lst.append([sum(row[0::2]),sum(row[1::2])])

temp = np.array(temp_lst)
# Calculate standard deviation and mean
std_x = np.std(temp, axis=0)  # Standard deviation along columns
std_y = np.std(temp, axis=1)  # Standard deviation along rows

mean_x = np.mean(temp, axis=0)  # Mean along columns
mean_y = np.mean(temp, axis=1)  # Mean along rows

print("Standard Deviation (axis=0):", std_x/np.linalg.norm(std_x))
print("Mean (axis=0):", mean_x/np.linalg.norm(mean_x))
# Out:
# Standard Deviation (axis=0): [0.38282967 0.92381895]
# Mean (axis=0): [ 0.00522235 -0.99998636]

# %%
df = pd.read_csv('landmark_differences_csvs/jaffe/ANG.csv')
temp_lst = []

for i in range(df.shape[0]):

    row = list(df.iloc[i])
    temp_lst.append([sum(row[0::2]),sum(row[1::2])])

temp = np.array(temp_lst)
# Calculate standard deviation and mean
std_x = np.std(temp, axis=0)  # Standard deviation along columns
std_y = np.std(temp, axis=1)  # Standard deviation along rows

mean_x = np.mean(temp, axis=0)  # Mean along columns
mean_y = np.mean(temp, axis=1)  # Mean along rows

print("Standard Deviation (axis=0):", std_x/np.linalg.norm(std_x))
print("Mean (axis=0):", mean_x/np.linalg.norm(mean_x))
# Out:
# Standard Deviation (axis=0): [0.36800972 0.92982194]
# Mean (axis=0): [ 0.0448096  -0.99899555]

# %%
df = pd.read_csv('landmark_differences_csvs/iim/ANG.csv')
temp_lst = []

for i in range(df.shape[0]):

    row = list(df.iloc[i])
    temp_lst.append([sum(row[0::2]),sum(row[1::2])])

temp = np.array(temp_lst)
# Calculate standard deviation and mean
std_x = np.std(temp, axis=0)  # Standard deviation along columns
std_y = np.std(temp, axis=1)  # Standard deviation along rows

mean_x = np.mean(temp, axis=0)  # Mean along columns
mean_y = np.mean(temp, axis=1)  # Mean along rows

print("Standard Deviation (axis=0):", std_x/np.linalg.norm(std_x))
print("Mean (axis=0):", mean_x/np.linalg.norm(mean_x))
# Out:
# Standard Deviation (axis=0): [0.27125618 0.96250719]
# Mean (axis=0): [-0.01325764 -0.99991211]

# %% [markdown]
# ### Plotting resultant vectorr for IIM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('landmark_differences_csvs/jaffe/ANG.csv')

temp_lst = []

# Compute resultant vectors
for i in range(df.shape[0]):
    row = list(df.iloc[i])
    resultant_vector = np.array([sum(row[0::2]), sum(row[1::2])])
    resultant_vector /= np.linalg.norm(resultant_vector)
    temp_lst.append(resultant_vector)

# Convert the list to a numpy array
vectors = np.array(temp_lst)

print(vectors)

# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

print(np.mean(vectors,axis=0))
# Out:
# [[-1.95923984e-01 -9.80619086e-01]
#  [ 2.72243502e-01 -9.62228391e-01]
#  [-1.66619986e-01 -9.86021187e-01]
#  [ 9.07593773e-03 -9.99958813e-01]
#  [ 9.74801025e-01 -2.23076134e-01]
#  [-2.57752812e-01 -9.66210892e-01]
#  [-2.40279372e-01 -9.70703777e-01]
#  [ 5.99974696e-02 -9.98198529e-01]
#  [-3.12213584e-02 -9.99512495e-01]
#  [ 8.91368763e-02 -9.96019386e-01]
#  [ 6.42955755e-01  7.65903321e-01]
#  [ 1.74909338e-01 -9.84584544e-01]
#  [ 1.13249843e-03 -9.99999359e-01]
#  [ 3.25083407e-02 -9.99471464e-01]
#  [-7.63887171e-02 -9.97078113e-01]
#  [-5.42620964e-01 -8.39977672e-01]
#  [ 4.62729265e-01 -8.86499649e-01]
#  [ 7.46300120e-04 -9.99999722e-01]
#  [ 5.02480374e-01 -8.64588616e-01]
#  [-5.42297131e-02 -9.98528486e-01]
#  [-4.86848810e-02 -9.98814188e-01]
#  [-9.47456945e-02 -9.95501508e-01]
#  [ 4.69141472e-02 -9.98898925e-01]
#  [ 9.21264698e-01  3.88936185e-01]
#  [-2.03054952e-01 -9.79167343e-01]
#  [-2.36971522e-02 -9.99719183e-01]
#  [ 1.08354606e-03 -9.99999413e-01]
#  [-4.19961311e-02 -9.99117773e-01]
#  [ 2.62004976e-02 -9.99656708e-01]
#  [-1.09989586e-01  9.93932740e-01]]
# [ 0.07103248 -0.78251264]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('landmark_differences_csvs/iim/ANG.csv')

temp_lst = []

# Compute resultant vectors
for i in range(df.shape[0]):
    row = list(df.iloc[i])
    resultant_vector = np.array([sum(row[0::2]), sum(row[1::2])])
    resultant_vector /= np.linalg.norm(resultant_vector)
    temp_lst.append(resultant_vector)

# Convert the list to a numpy array
vectors = np.array(temp_lst)

# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

print(np.mean(vectors,axis=0))
# Out:
# [-0.06684041 -0.7670022 ]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('landmark_differences_csvs/radboud/ANG.csv')

temp_lst = []

# Compute resultant vectors
for i in range(df.shape[0]):
    row = list(df.iloc[i])
    resultant_vector = np.array([sum(row[0::2]), sum(row[1::2])])
    resultant_vector /= np.linalg.norm(resultant_vector)
    temp_lst.append(resultant_vector)

# Convert the list to a numpy array
vectors = np.array(temp_lst)

# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

print(np.mean(vectors,axis=0))
# Out:
# [ 0.03214609 -0.7425384 ]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Define the array
temp = np.array([[0.03214609, -0.7425384],
                 [-0.06684041, -0.7670022],
                 [0.07103248, -0.78251264]])

# Compute cosine similarity between each pair of vectors
cosine_sim_matrix = cosine_similarity(temp)

# Print the pairwise cosine similarity matrix
print("Cosine Similarity Matrix:")
print(cosine_sim_matrix)
# Out:
# Cosine Similarity Matrix:
# [[1.         0.99153717 0.99888338]
#  [0.99153717 1.         0.98429664]
#  [0.99888338 0.98429664 1.        ]]

# %%
iim_ang = np.array([34, 36, 38, 66, 88, 118, 168, 170, 172, 184, 214, 272, 274, 278, 282, 298, 300, 302, 306, 340, 342, 344, 346, 352, 354, 364, 366, 390, 400, 402, 404, 406, 410, 418, 422, 424, 430, 526, 548, 628, 630, 632, 672, 730, 732, 736, 740, 756, 758, 760, 790, 792, 794, 796, 802, 812, 814, 838, 844, 846, 850, 858, 862, 864])
radboud_ang = np.array([38, 66, 88, 118, 168, 214, 272, 274, 278, 282, 298, 300, 302, 306, 340, 342, 344, 346, 352, 354, 366, 386, 390, 400, 402, 404, 406, 410, 418, 422, 424, 430, 432, 526, 578, 628, 672, 730, 732, 736, 740, 756, 758, 760, 790, 792, 794, 796, 802, 814, 838, 844, 846, 850, 858, 862, 864, 870, 872])

intersection = np.intersect1d(iim_ang, radboud_ang)

print("Intersection:", intersection)
# Out:
# Intersection: [ 38  66  88 118 168 214 272 274 278 282 298 300 302 306 340 342 344 346
#  352 354 366 390 400 402 404 406 410 418 422 424 430 526 628 672 730 732
#  736 740 756 758 760 790 792 794 796 802 814 838 844 846 850 858 862 864]

# %%
new_array = []
for element in intersection:
    new_array.append(element)  # Add the element itself
    if element % 2 == 0:  # Check if even
        new_array.append(element - 1)
    else:  # If odd
        new_array.append(element + 1)

intersection = np.array(sorted(list(set(new_array))))

# %%
intersection
# Out:
# array([ 37,  38,  65,  66,  87,  88, 117, 118, 167, 168, 213, 214, 271,
#        272, 273, 274, 277, 278, 281, 282, 297, 298, 299, 300, 301, 302,
#        305, 306, 339, 340, 341, 342, 343, 344, 345, 346, 351, 352, 353,
#        354, 365, 366, 389, 390, 399, 400, 401, 402, 403, 404, 405, 406,
#        409, 410, 417, 418, 421, 422, 423, 424, 429, 430, 525, 526, 627,
#        628, 671, 672, 729, 730, 731, 732, 735, 736, 739, 740, 755, 756,
#        757, 758, 759, 760, 789, 790, 791, 792, 793, 794, 795, 796, 801,
#        802, 813, 814, 837, 838, 843, 844, 845, 846, 849, 850, 857, 858,
#        861, 862, 863, 864])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('landmark_differences_csvs/iim/ANG.csv')

df = df.sample(30)

print(df.shape)

df = df[[str(x) for x in intersection]]


temp_lst = []
magnitude = 0
# Compute resultant vectors
for i in range(df.shape[0]):
    row = list(df.iloc[i])
    resultant_vector = np.array([sum(row[0::2]), sum(row[1::2])])
    magnitude += np.linalg.norm(resultant_vector)
    resultant_vector /= np.linalg.norm(resultant_vector)
    temp_lst.append(resultant_vector)

magnitude /= 30

print("Magnitude:",magnitude)
# Convert the list to a numpy array
vectors = np.array(temp_lst)

# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

print(np.mean(vectors,axis=0))
# Out:
# (30, 936)
# Magnitude: 6131.538795448334
# [-0.0049101  -0.78797268]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('landmark_differences_csvs/radboud/ANG.csv')

df = df.sample(30)
print(df.shape)
df = df[[str(x) for x in intersection]]

temp_lst = []
magnitude = 0
# Compute resultant vectors
for i in range(df.shape[0]):
    row = list(df.iloc[i])
    resultant_vector = np.array([sum(row[0::2]), sum(row[1::2])])
    magnitude += np.linalg.norm(resultant_vector)
    resultant_vector /= np.linalg.norm(resultant_vector)
    temp_lst.append(resultant_vector)

magnitude /= 30

print("Magnitude:",magnitude)
# Convert the list to a numpy array
vectors = np.array(temp_lst)

# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

print(np.mean(vectors,axis=0))
# Out:
# (30, 936)
# Magnitude: 6068.9824177164455
# [ 0.00679309 -0.74629196]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Define the array
temp = np.array([[-0.11929707, -0.62879505],
                 [ 0.04028202, -0.90317018]])

vectors = temp
# Prepare the origin points (set to (0, 0) for all vectors)
origin_x = np.zeros(vectors.shape[0])
origin_y = np.zeros(vectors.shape[0])

# Separate the x and y components of the vectors
vector_x = vectors[:, 0]
vector_y = vectors[:, 1]

# Plot the vectors
plt.figure(figsize=(8, 8))
plt.quiver(origin_x, origin_y, vector_x, vector_y, angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.grid()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('2D Vectors')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# Compute cosine similarity between each pair of vectors
cosine_sim_matrix = cosine_similarity(temp)

# Print the pairwise cosine similarity matrix
print("Cosine Similarity Matrix:")
print(cosine_sim_matrix)
# Out:
# Cosine Similarity Matrix:
# [[1.         0.97319331]
#  [0.97319331 1.        ]]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Define the array
temp = np.array([[ 1557266, -7473771],
                 [-6220323,-6725124]])

# Compute cosine similarity between each pair of vectors
cosine_sim_matrix = cosine_similarity(temp)

# Print the pairwise cosine similarity matrix
print("Cosine Similarity Matrix:")
print(cosine_sim_matrix)
# Out:
# Cosine Similarity Matrix:
# [[1.         0.58017861]
#  [0.58017861 1.        ]]

# %%
# Define the array
temp = np.array([[ 0.1557266, -0.07473771],
                 [-0.06220323,-0.6725124]])

# %%
from scipy.stats import ttest_ind, ttest_rel


vector1 = [ 0.00679309 -0.74629196]
vector2 = [-0.06220323,-0.6725124]
# For independent samples
stat, p = ttest_ind(vector1, vector2)

# For paired samples
# stat, p = ttest_rel(vector1, vector2)

print(p)

if p < 0.05:
    print("The vectors are statistically different.")
else:
    print("No significant difference between the vectors.")
# Out:
# 0.609456403331768
# No significant difference between the vectors.

# %%
from scipy.stats import mannwhitneyu

# Example:
stat, p_value = mannwhitneyu(vector1, vector2, alternative='two-sided')
if p_value < 0.05:
    print("Statistically different")
else:
    print("Not statistically different")
# Out:
# Not statistically different
